# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as GridSpec
import seaborn as sns

# %%
diamonds = (
    pd.read_csv("Data/Diamonds Prices2022.csv")
    .drop(["Unnamed: 0"], axis=1)
)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # Gridspec

# %%
fig = plt.figure(constrained_layout = True)

grid = GridSpec.GridSpec(8, 8, figure = fig)

ax1 = fig.add_subplot(grid[2:7, 0:6])
ax1.scatter(
    diamonds["carat"],
    diamonds["price"],
    alpha=.3
)

ax2 = fig.add_subplot(grid[0:2, 0:6])
ax2.hist(diamonds["carat"])

ax3 = fig.add_subplot(grid[2:7, 6:])
ax3.hist(diamonds["price"],
         orientation="horizontal")

plt.show()

# %% [markdown]
# # Color Palettes

# %% [markdown]
# https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
data = [x for x in range(10)]
data2 = [x * 2 for x in range (10)]
data3 = [x * 3 for x in range(10)]
data4 = [x * 4 for x in range(10)]

# %%
plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.Dark2.colors) #color=["brown", "red", "orange", "yellow"])

# %%
color_list=["green", "purple"]

fig, ax = plt.subplots()

ax.plot(
    data
)

ax.plot(
    data2
)

ax.plot(
    data3
)

ax.plot(
    data4
)

# %% [markdown]
# # Style Sheets

# %%
# plt.style.use("ggplot")
plt.style.use("Solarize_Light2")

# %%
plt.plot([1, 2, 3], c="red") # Colors can still be changed
plt.show()

# %% [markdown]
# # Style Parameters

# %% [markdown]
# rcParameter = Runtime Configuration Parameters

# %%
plt.style.library["Solarize_Light2"]
# Out:
# RcParams({'axes.axisbelow': True,
#           'axes.edgecolor': '#eee8d5',
#           'axes.facecolor': '#eee8d5',
#           'axes.grid': True,
#           'axes.labelcolor': '#657b83',
#           'axes.labelsize': 12.0,
#           'axes.prop_cycle': cycler('color', ['#268BD2', '#2AA198', '#859900', '#B58900', '#CB4B16', '#DC322F', '#D33682', '#6C71C4']),
#           'axes.titlesize': 16.0,
#           'figure.facecolor': '#FDF6E3',
#           'grid.color': '#fdf6e3',
#           'grid.linestyle': '-',
#           'grid.linewidth': 1.0,
#           'lines.linewidth': 2.0,
#           'lines.solid_capstyle': <CapStyle.butt: 'butt'>,
#           'patch.antialiased': True,
#           'xtick.color': '#657b83',
#           'xtick.direction': 'out',
#           'ytick.color': '#657b83',
#           'ytick.direction': 'out'})

# %%
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %%
# Changing rcParameters

plt.style.use("default")
plt.rc("axes.spines", right=False, top=False)
plt.rc("axes", titlesize=20)
plt.rc("lines", linestyle="--")
plt.rcParams["figure.figsize"] = (8, 6)

# %%
data = [x for x in range(10)]

fig, ax = plt.subplots()

ax.plot(
    data
)

plt.show()

# %% [markdown]
# # Saving Figures

# %%
# plt.savefig("filename.jpeg", dpi=1000)
# plt.savefig("filename") # default extension = png, default dpi = 100
